# %% [markdown]
# # Excercise 1: Basic Python API #
#
# The goal of this excercise is to get familiar with the TiGL API and its concepts.
#  - You should traverse trough the CPACS tree, get the wing shape.
#  - Create a box with OpenCASCADE
#  - Export both with the TiGL IGES exporter with custom layers
#
# ## Loading the modules ##
# As usual, load the required TiGL and TiXI modules

# %%
from tixi3 import tixi3wrapper
from tigl3 import tigl3wrapper
import tigl3.configuration

# %% [markdown]
# Now open a the CPACS file simpletest.xml using the "old" high-level python API.

# %%
tixi_h = tixi3wrapper.Tixi3()
tigl_h = tigl3wrapper.Tigl3()

tixi_h.open("../../cpacs/simpletest.cpacs.xml")
tigl_h.open(tixi_h, "")

# %% [markdown]
# ## CPACS Traversal ##
# First, get the configuration manager from tigl3.configuration and retrieve the aircraft configuration.
#
# __Hint: CCPACSConfigurationManager_get_instance() gets the global configuration manager object__

# %%
# get the configuration manager
mgr = tigl3.configuration.CCPACSConfigurationManager_get_instance()

# %% [markdown]
# Get the aircraft config. Now, both "old" and "new" API come together, when we have to pass the TiGL handle to the configuration manager.

# %%
aircraft_config = mgr.get_configuration(tigl_h._handle.value)

# %% [markdown]
# Get the wing from the aircraft confiuration and print its wing uid. Check, what method the wing object offers.

# %%
wing = aircraft_config.get_wing(1)

# %%
print(wing.get_uid())
# Out:
# Wing

# %%
help(wing)
# Out:
# Help on CCPACSWing in module tigl3.configuration object:
#
# class CCPACSWing(CPACSWing, CTiglRelativelyPositionedComponent)
#  |  C++ includes: CCPACSWing.h
#  |
#  |  Method resolution order:
#  |      CCPACSWing
#  |      CPACSWing
#  |      CTiglRelativelyPositionedComponent
#  |      tigl3.geometry.CTiglAbstractGeometricComponent
#  |      tigl3.geometry.ITiglGeometricComponent
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __del__ lambda self
#  |
#  |  __getattr__ lambda self, name
#  |
#  |  __init__(self, *args)
#  |      __init__(tigl::CCPACSWing self, CCPACSWings parent, CTiglUIDManager uidMgr) -> CCPACSWing
#  |
#  |      Parameters
#  |      ----------
#  |      parent: tigl::CCPACSWings *
#  |      uidMgr: tigl::CTiglUIDManager *
#  |
#  |      __init__(tigl::CCPACSWing self, tigl::CCPACSRotorBlades * parent, CTiglUIDManager uidMgr) -> CCPACSWing
#  |
#  |      Parameters
#  |      ----------
#  |      parent: tigl::CCPACSRotorBlades *
#  |      uidMgr: tigl::CTiglUIDManager *
#  |
#  |  __repr__ = _swig_repr(self)
#  |
#  |  __setattr__ lambda self, name, value
#  |
#  |  __swig_destroy__ = delete_CCPACSWing(...)
#  |      delete_CCPACSWing(CCPACSWing self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_aspect_ratio(self)
#  |      get_aspect_ratio(CCPACSWing self) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_chord_point(self, segmentIndex, eta, xsi, referenceCS=0)
#  |      get_chord_point(CCPACSWing self, int segmentIndex, double eta, double xsi, TiglCoordinateSystem referenceCS=GLOBAL_COORDINATE_SYSTEM) -> gp_Pnt
#  |
#  |      Parameters
#  |      ----------
#  |      segmentIndex: int
#  |      eta: double
#  |      xsi: double
#  |      referenceCS: enum TiglCoordinateSystem
#  |
#  |      get_chord_point(CCPACSWing self, int segmentIndex, double eta, double xsi) -> gp_Pnt
#  |
#  |      Parameters
#  |      ----------
#  |      segmentIndex: int
#  |      eta: double
#  |      xsi: double
#  |
#  |  get_component_intent(self)
#  |      get_component_intent(CCPACSWing self) -> TiglGeometricComponentIntent
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  get_component_segment(self, *args)
#  |      get_component_segment(CCPACSWing self, int const index) -> CCPACSWingComponentSegment
#  |
#  |      Parameters
#  |      ----------
#  |      index: int const
#  |
#  |      get_component_segment(CCPACSWing self, int const index) -> CCPACSWingComponentSegment
#  |
#  |      Parameters
#  |      ----------
#  |      index: int const
#  |
#  |      get_component_segment(CCPACSWing self, std::string const & uid) -> CCPACSWingComponentSegment
#  |
#  |      Parameters
#  |      ----------
#  |      uid: std::string const &
#  |
#  |  get_component_segment_count(self)
#  |      get_component_segment_count(CCPACSWing self) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  get_component_type(self)
#  |      get_component_type(CCPACSWing self) -> TiglGeometricComponentType
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  get_configuration(self)
#  |      get_configuration(CCPACSWing self) -> CCPACSConfiguration
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  get_defaulted_uid(self)
#  |      get_defaulted_uid(CCPACSWing self) -> std::string
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  get_guide_curve_points(self)
#  |      get_guide_curve_points(CCPACSWing self) -> CPointContainer
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_guide_curve_segment(self, uid)
#  |      get_guide_curve_segment(CCPACSWing self, std::string uid) -> tigl::CCPACSGuideCurve &
#  |
#  |      Parameters
#  |      ----------
#  |      uid: std::string
#  |
#  |  get_guide_curve_wires(self)
#  |      get_guide_curve_wires(CCPACSWing self) -> TopoDS_Compound
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  get_loft_with_leading_edge(self)
#  |      get_loft_with_leading_edge(CCPACSWing self) -> TopoDS_Shape &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_lower_point(self, segmentIndex, eta, xsi)
#  |      get_lower_point(CCPACSWing self, int segmentIndex, double eta, double xsi) -> gp_Pnt
#  |
#  |      Parameters
#  |      ----------
#  |      segmentIndex: int
#  |      eta: double
#  |      xsi: double
#  |
#  |  get_lower_segment_surface(self, index)
#  |      get_lower_segment_surface(CCPACSWing self, int index) -> Handle_Geom_Surface
#  |
#  |      Parameters
#  |      ----------
#  |      index: int
#  |
#  |  get_lower_shape(self)
#  |      get_lower_shape(CCPACSWing self) -> TopoDS_Shape &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_positioning_transformation(self, sectionUID)
#  |      get_positioning_transformation(CCPACSWing self, std::string sectionUID) -> CTiglTransformation
#  |
#  |      Parameters
#  |      ----------
#  |      sectionUID: std::string
#  |
#  |  get_reference_area(self, symPlane)
#  |      get_reference_area(CCPACSWing self, TiglSymmetryAxis symPlane) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      symPlane: enum TiglSymmetryAxis
#  |
#  |  get_section(self, *args)
#  |      get_section(CCPACSWing self, int index) -> CCPACSWingSection
#  |
#  |      Parameters
#  |      ----------
#  |      index: int
#  |
#  |      get_section(CCPACSWing self, int index) -> CCPACSWingSection
#  |
#  |      Parameters
#  |      ----------
#  |      index: int
#  |
#  |  get_section_count(self)
#  |      get_section_count(CCPACSWing self) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  get_segment(self, *args)
#  |      get_segment(CCPACSWing self, int const index) -> CCPACSWingSegment
#  |
#  |      Parameters
#  |      ----------
#  |      index: int const
#  |
#  |      get_segment(CCPACSWing self, int const index) -> CCPACSWingSegment
#  |
#  |      Parameters
#  |      ----------
#  |      index: int const
#  |
#  |      get_segment(CCPACSWing self, std::string uid) -> CCPACSWingSegment
#  |
#  |      Parameters
#  |      ----------
#  |      uid: std::string
#  |
#  |      get_segment(CCPACSWing self, std::string uid) -> CCPACSWingSegment
#  |
#  |      Parameters
#  |      ----------
#  |      uid: std::string
#  |
#  |  get_segment_count(self)
#  |      get_segment_count(CCPACSWing self) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  get_segment_eta_xsi(self, xyz, eta, xsi, onTop)
#  |      get_segment_eta_xsi(CCPACSWing self, gp_Pnt const & xyz, double & eta, double & xsi, bool & onTop) -> int
#  |
#  |      Parameters
#  |      ----------
#  |      xyz: gp_Pnt const &
#  |      eta: double &
#  |      xsi: double &
#  |      onTop: bool &
#  |
#  |  get_surface_area(self)
#  |      get_surface_area(CCPACSWing self) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_upper_point(self, segmentIndex, eta, xsi)
#  |      get_upper_point(CCPACSWing self, int segmentIndex, double eta, double xsi) -> gp_Pnt
#  |
#  |      Parameters
#  |      ----------
#  |      segmentIndex: int
#  |      eta: double
#  |      xsi: double
#  |
#  |  get_upper_segment_surface(self, index)
#  |      get_upper_segment_surface(CCPACSWing self, int index) -> Handle_Geom_Surface
#  |
#  |      Parameters
#  |      ----------
#  |      index: int
#  |
#  |  get_upper_shape(self)
#  |      get_upper_shape(CCPACSWing self) -> TopoDS_Shape &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_volume(self)
#  |      get_volume(CCPACSWing self) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_wetted_area(self, parent)
#  |      get_wetted_area(CCPACSWing self, TopoDS_Shape parent) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      parent: TopoDS_Shape
#  |
#  |  get_wing_mac(self)
#  |      get_wing_mac(CCPACSWing self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  get_wingspan(self)
#  |      get_wingspan(CCPACSWing self) -> double
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  invalidate(self)
#  |      invalidate(CCPACSWing self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing *
#  |
#  |  is_rotor_blade(self)
#  |      is_rotor_blade(CCPACSWing self) -> bool
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CCPACSWing const *
#  |
#  |  read_cpacs(self, tixiHandle, wingXPath)
#  |      read_cpacs(CCPACSWing self, int const & tixiHandle, std::string const & wingXPath)
#  |
#  |      Parameters
#  |      ----------
#  |      tixiHandle: int const &
#  |      wingXPath: std::string const &
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __swig_getmethods__ = {}
#  |
#  |  __swig_setmethods__ = {}
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from CPACSWing:
#  |
#  |  get_component_segments(self, *args)
#  |      get_component_segments(CPACSWing self) -> boost::optional< tigl::CCPACSWingComponentSegments > const
#  |      get_component_segments(CPACSWing self) -> boost::optional< tigl::CCPACSWingComponentSegments >
#  |      get_component_segments(CPACSWing self, CreateIfNotExistsTag arg2) -> CCPACSWingComponentSegments
#  |
#  |      Parameters
#  |      ----------
#  |      arg2: tigl::CreateIfNotExistsTag
#  |
#  |  get_description(self)
#  |      get_description(CPACSWing self) -> boost::optional< std::string > const &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing const *
#  |
#  |  get_name(self)
#  |      get_name(CPACSWing self) -> std::string const &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing const *
#  |
#  |  get_parent_uid(self)
#  |      get_parent_uid(CPACSWing self) -> boost::optional< std::string > const &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing const *
#  |
#  |  get_positionings(self, *args)
#  |      get_positionings(CPACSWing self) -> boost::optional< tigl::CCPACSPositionings > const
#  |      get_positionings(CPACSWing self) -> boost::optional< tigl::CCPACSPositionings >
#  |      get_positionings(CPACSWing self, CreateIfNotExistsTag arg2) -> CCPACSPositionings
#  |
#  |      Parameters
#  |      ----------
#  |      arg2: tigl::CreateIfNotExistsTag
#  |
#  |  get_sections(self, *args)
#  |      get_sections(CPACSWing self) -> CCPACSWingSections
#  |      get_sections(CPACSWing self) -> CCPACSWingSections
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing *
#  |
#  |  get_segments(self, *args)
#  |      get_segments(CPACSWing self) -> tigl::CCPACSWingSegments const
#  |      get_segments(CPACSWing self) -> tigl::CCPACSWingSegments &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing *
#  |
#  |  get_symmetry(self)
#  |      get_symmetry(CPACSWing self) -> boost::optional< TiglSymmetryAxis > const &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing const *
#  |
#  |  get_transformation(self, *args)
#  |      get_transformation(CPACSWing self) -> CCPACSTransformation
#  |      get_transformation(CPACSWing self) -> CCPACSTransformation
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing *
#  |
#  |  get_uid(self)
#  |      get_uid(CPACSWing self) -> std::string const &
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing const *
#  |
#  |  get_uidmanager(self, *args)
#  |      get_uidmanager(CPACSWing self) -> CTiglUIDManager
#  |      get_uidmanager(CPACSWing self) -> CTiglUIDManager
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing const *
#  |
#  |  remove_component_segments(self)
#  |      remove_component_segments(CPACSWing self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing *
#  |
#  |  remove_positionings(self)
#  |      remove_positionings(CPACSWing self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::generated::CPACSWing *
#  |
#  |  set_description(self, value)
#  |      set_description(CPACSWing self, boost::optional< std::string > const & value)
#  |
#  |      Parameters
#  |      ----------
#  |      value: boost::optional< std::string > const &
#  |
#  |  set_name(self, value)
#  |      set_name(CPACSWing self, std::string const & value)
#  |
#  |      Parameters
#  |      ----------
#  |      value: std::string const &
#  |
#  |  set_parent_uid(self, value)
#  |      set_parent_uid(CPACSWing self, boost::optional< std::string > const & value)
#  |
#  |      Parameters
#  |      ----------
#  |      value: boost::optional< std::string > const &
#  |
#  |  set_symmetry(self, value)
#  |      set_symmetry(CPACSWing self, boost::optional< TiglSymmetryAxis > const & value)
#  |
#  |      Parameters
#  |      ----------
#  |      value: boost::optional< TiglSymmetryAxis > const &
#  |
#  |  set_uid(self, value)
#  |      set_uid(CPACSWing self, std::string const & value)
#  |
#  |      Parameters
#  |      ----------
#  |      value: std::string const &
#  |
#  |  write_cpacs(self, tixiHandle, xpath)
#  |      write_cpacs(CPACSWing self, int const & tixiHandle, std::string const & xpath)
#  |
#  |      Parameters
#  |      ----------
#  |      tixiHandle: int const &
#  |      xpath: std::string const &
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from CPACSWing:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from CTiglRelativelyPositionedComponent:
#  |
#  |  get_children(self, recursive)
#  |      get_children(CTiglRelativelyPositionedComponent self, bool recursive) -> tigl::CTiglRelativelyPositionedComponent::ChildContainerType
#  |
#  |      Parameters
#  |      ----------
#  |      recursive: bool
#  |
#  |  get_rotation(self)
#  |      get_rotation(CTiglRelativelyPositionedComponent self) -> CTiglPoint
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglRelativelyPositionedComponent const *
#  |
#  |  get_scaling(self)
#  |      get_scaling(CTiglRelativelyPositionedComponent self) -> CTiglPoint
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglRelativelyPositionedComponent const *
#  |
#  |  get_symmetry_axis(self)
#  |      get_symmetry_axis(CTiglRelativelyPositionedComponent self) -> TiglSymmetryAxis
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglRelativelyPositionedComponent const *
#  |
#  |  get_transformation_matrix(self)
#  |      get_transformation_matrix(CTiglRelativelyPositionedComponent self) -> CTiglTransformation
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglRelativelyPositionedComponent const *
#  |
#  |  get_translation(self)
#  |      get_translation(CTiglRelativelyPositionedComponent self) -> CTiglPoint
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglRelativelyPositionedComponent const *
#  |
#  |  get_translation_type(self)
#  |      get_translation_type(CTiglRelativelyPositionedComponent self) -> tigl::ECPACSTranslationType
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglRelativelyPositionedComponent const *
#  |
#  |  reset(self)
#  |      reset(CTiglRelativelyPositionedComponent self)
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglRelativelyPositionedComponent *
#  |
#  |  set_symmetry_axis(self, axis)
#  |      set_symmetry_axis(CTiglRelativelyPositionedComponent self, TiglSymmetryAxis const & axis)
#  |
#  |      Parameters
#  |      ----------
#  |      axis: TiglSymmetryAxis const &
#  |
#  |  set_transformation(self, transform)
#  |      set_transformation(CTiglRelativelyPositionedComponent self, CCPACSTransformation transform)
#  |
#  |      Parameters
#  |      ----------
#  |      transform: tigl::CCPACSTransformation const &
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from tigl3.geometry.CTiglAbstractGeometricComponent:
#  |
#  |  get_is_on(self, pnt)
#  |      get_is_on(CTiglAbstractGeometricComponent self, gp_Pnt const & pnt) -> bool
#  |
#  |      Parameters
#  |      ----------
#  |      pnt: gp_Pnt const &
#  |
#  |  get_is_on_mirrored(self, pnt)
#  |      get_is_on_mirrored(CTiglAbstractGeometricComponent self, gp_Pnt const & pnt) -> bool
#  |
#  |      Parameters
#  |      ----------
#  |      pnt: gp_Pnt const &
#  |
#  |  get_loft(self)
#  |      get_loft(CTiglAbstractGeometricComponent self) -> PNamedShape
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglAbstractGeometricComponent const *
#  |
#  |  get_mirrored_loft(self)
#  |      get_mirrored_loft(CTiglAbstractGeometricComponent self) -> PNamedShape
#  |
#  |      Parameters
#  |      ----------
#  |      self: tigl::CTiglAbstractGeometricComponent *

# %% [markdown]
# ## Wing trailing edge renaming ##
#
# Now next tasks are:
#  - Get the wing shape
#  - Print all face names of the wing
#  - Rename the trailing edge faces

# %%
wing_shape = wing.get_loft()

# %%
for iface in range(0, wing_shape.get_face_count()):
    if wing_shape.get_face_traits(iface).name() == "TrailingEdge":
        wing_shape.get_face_traits(iface).set_name("EdgeTrail")
    print(wing_shape.get_face_traits(iface).name())
# Out:
# Bottom
# Top
# EdgeTrail
# Bottom
# Top
# EdgeTrail
# Inside
# Outside

# %% [markdown]
# ## Create named shape with a box ##
#
# - Create a box with OpenCASCADE. You can use the BRepPrimAPI_MakeBox class from the OCC.BRepPrimAPI package.
# - Then, create a named shape from the TopoDS_Shape.

# %%
from OCC.BRepPrimAPI import BRepPrimAPI_MakeBox
box = BRepPrimAPI_MakeBox(0.3, 0.8, 0.3).Solid()

# %%
from tigl3.geometry import CNamedShape
box_ns = CNamedShape(box, "MyBox")

# %% [markdown]
# ## Export of the shapes ##
# Finally, you have to export both shapes into the IGES format. Both shapes should have a different IGES layer!
#
# You can inspect the result in TiGL Viewer by drag-and-dropping the igs file into the viewer.

# %%
from tigl3.exports import create_exporter, IgesShapeOptions
iges_exporter = create_exporter("igs")
iges_exporter.add_shape(wing_shape, IgesShapeOptions(1111))
iges_exporter.add_shape(box_ns, IgesShapeOptions(2222))
iges_exporter.write("ex1.igs")
# Out:
# True
